# %%
import trafilatura
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate
from langchain_community.document_loaders import PyPDFLoader
import tempfile
import requests
import json
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Initialize our Local LLM
llm = OllamaLLM(model="llama3.1", format="json")

# Configuration
KEYWORDS = ["licenta", "master", "doctorat", "calendar", "taxe", "acte", "admitere", "candidati"]
BAD_KEYWORDS = ["anunt", "finalizare", "xls", "teze", "docx", "plan"]
START_URLS = ["https://www.tuiasi.ro/admitere", 
              "https://ac.tuiasi.ro/admitere", 
              "https://arh.tuiasi.ro/admitere-2025/", 
              "https://etti.tuiasi.ro/admitere", 
              "https://icpm.tuiasi.ro/admitere/", 
              "https://ci.tuiasi.ro/admitere/", 
              "https://cmmi.tuiasi.ro/admitere/", 
              "https://hgim.tuiasi.ro/admitere/",  
              "https://ieeia.tuiasi.ro/admitere/", 
              "https://mec.tuiasi.ro/admitere/", 
              "https://sim.tuiasi.ro/admitere/", 
              "https://dima.tuiasi.ro/admitere/"]

# %%
def get_page_links(url):
    """
    Extracts and cleans internal links from a page, filtering only those 
    that contain specific admission-related keywords in the URL string.
    """
    try:
        downloaded = trafilatura.fetch_url(url)
        if not downloaded:
            return []
        
        soup = BeautifulSoup(downloaded, "html.parser")
        absolute_links = set()
        base_domain = urlparse(url).netloc
        
        for a_tag in soup.find_all("a", href=True):
            href = a_tag["href"].lower()
            full_url = urljoin(url, href)
            
            parsed_url = urlparse(full_url)
            clean_link = f"{parsed_url.scheme}://{parsed_url.netloc}{parsed_url.path}".rstrip('/')
            
            # 1. Domain Check: Must stay on the same faculty/university domain
            if base_domain in parsed_url.netloc and parsed_url.scheme in ["http", "https"]:
                
                # 2. Keyword Check: Does the URL contain any of our keywords?
                # We check the 'clean_link' string to see if keywords like 'taxe' or 'licenta' appear
                has_good_word = any(word in clean_link for word in KEYWORDS)
                has_bad_word = any(word in clean_link for word in BAD_KEYWORDS)
                
                if has_good_word and not has_bad_word:
                    absolute_links.add(clean_link)
                
        return list(absolute_links)
    except Exception as e:
        print(f"⚠️ Error fetching links from {url}: {e}")
        return []

# %%
queue = [(url, 0) for url in START_URLS]
visited = set()
all_discovered_links = set()

while queue:
    current_url, depth = queue.pop(0)
    
    if current_url in visited:
        continue
    
    visited.add(current_url)
    all_discovered_links.add(current_url)
    
    prefix = "  " * depth + "└─"
    print(f"{prefix} [{depth}] Visiting: {current_url}")
    
    if depth < MAX_DEPTH:
        sublinks = get_page_links(current_url)
        
        new_links_found = 0
        for link in sublinks:
            if link not in visited:
                queue.append((link, depth + 1))
                new_links_found += 1
        
        if new_links_found > 0:
            pass 

with open("urls.txt", "w", encoding="utf-8") as f:
    for link in sorted(all_discovered_links):
        f.write(f"{link}\n")

print("💾 Listsaved in 'urls.txt'.")
# Out:
# └─ [0] Visiting: https://www.tuiasi.ro/admitere
# └─ [0] Visiting: https://ac.tuiasi.ro/admitere
# └─ [0] Visiting: https://arh.tuiasi.ro/admitere-2025/
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/studii/master
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere/licenta/formular-de-inscriere-online-licenta
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere/licenta/informatii-generale
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere/admitere-doctorat
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/studii/licenta
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere/licenta/numar-de-locuri
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere-master
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere/licenta
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/studii/doctorat
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere/licenta/candidati-romani-de-pretutindeni
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/admitere/licenta/acte-necesare-pentru-admiterea-la-licenta
#   └─ [1] Visiting: https://cmmi.tuiasi.ro/studenti/taxe
#   └─ [1] Visiting: https://hgim.tuiasi.ro/studenti/taxe
#   └─ [1] Visiting: https://hgim.tuiasi.ro/proiectul-practeh
#   └─ [1] Visiting: https://hgim.tuiasi.ro/admitere/master
#   └─ [1] Visiting: https://hgim.tuiasi.ro/admitere
#   └─ [1] Visiting: https://hgim.tuiasi.ro/admitere/licenta
#   └─ [1] Visiting: https://hgim.tuiasi.ro/studii/master
#   └─ [1] Visiting: https://hgim.tuiasi.ro/studii/licenta
#   └─ [1] Visiting: https://hgim.tuiasi.ro/studii/doctorat
#   └─ [1] Visiting: https://hgim.tuiasi.ro/admitere/doctorat
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/studii/licenta
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/studenti/taxe
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/admitere/admitere-master
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/curricula-master
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/studii/master-si-doctorat
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/admitere/admitere-licenta
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/calendarul-anului-universitar
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/doctorat
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/admitere
#   └─ [1] Visiting: https://ieeia.tuiasi.ro/admitere/admitere-doctorat
#   └─ [1] Visiting: https://mec.tuiasi.ro/prelucrarea-datelor-cu-caracter-personal-gdpr
#   └─ [1] Visiting: https://mec.tuiasi.ro/contracte-de-studii
#   └─ [1] Visiting: https://mec.tuiasi.ro/2022-2/admitere-la-masterat
#   └─ [1] Visiting: https://mec.tuiasi.ro/studii/masterat
#   └─ [1] Visiting: https://mec.tuiasi.ro/admitere/informatii-importante
#   └─ [1] Visiting: https://mec.tuiasi.ro/studii/licenta
#   └─ [1] Visiting: https://mec.tuiasi.ro/studii/doctorat
#   └─ [1] Visiting: https://mec.tuiasi.ro/taxe
            loader = PyPDFLoader(url)
            pages = loader.load()
            return "\n".join([p.page_content for p in pages])
        else:
            downloaded = trafilatura.fetch_url(url)
            return trafilatura.extract(downloaded) if downloaded else None
    except Exception as e:
        print(f"⚠️ Error fetching content from {url}: {e}")
        return None

def get_faculty_tag(url):
    domain = urlparse(url).netloc
    parts = domain.split('.')
    if len(parts) >= 3 and parts[-2] == "tuiasi":
        return parts[0].upper()
    return "TUIASI_CENTRAL"

# %%
url_check_prompt = PromptTemplate.from_template("""
Analizează următorul URL de la Universitatea TUIASI: {url}
Anul curent de interes: 2026.

Sarcina: Decide dacă acest link pare să conțină informații esențiale pentru admitere (Acte, Taxe, Calendar, Metodologie, Programe de studiu).
Atenție: Respinge link-urile care conțin "2025", "2024" sau ani anteriori în URL.

Răspunde DOAR JSON:
{{
    "is_important": true/false,
    "topic": "licenta/master/doctorat/general",
    "content_type": "taxe/acte/calendar/metodologie/programe/alta"
}}
""")

extraction_prompt = PromptTemplate.from_template("""
Ești un asistent de admitere TUIASI 2026. Extrage informațiile relevante din textul de mai jos.
URL sursă: {url}

TEXT RAW:
{raw_content}

Sarcina:
1. Dacă textul confirmă că este vorba despre admiterea 2026 sau reguli generale valabile, extrage detaliile. Informatii de interes: 
    - Acte necesare (dosar de înscriere)
    - Taxe și finanțare
    - Calendarul admiterii
    - Reguli / Metodologii / Condiții
    - Informatii despre programele de studiu
2. Formatează totul în Markdown curat.
3. Ignoră meniurile de navigare, subsolurile sau reclamele.

Răspunde DOAR JSON:
{{
    "is_valid_2026": true/false,
    "structured_text": "conținutul markdown aici...",
    "detected_tags": ["tag1", "tag2"]
}}
""")

# %%
processed_docs = []
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=200)

with open("urls.txt", "r", encoding="utf-8") as f:
    urls = [line.strip() for line in f.readlines()]

for url in urls:
    faculty = get_faculty_tag(url)
    
    try:
        url_resp = llm.invoke(url_check_prompt.format(url=url))
        url_data = json.loads(url_resp)
        
        if not url_data["is_important"]:
            print(f"⏩ Ignored: {url}")
            continue
            
        raw_text = get_page_content(url)
        
        if not raw_text or len(raw_text) < 200:
            continue
            
        extract_resp = llm.invoke(extraction_prompt.format(url=url, raw_content=raw_text))
        extract_data = json.loads(extract_resp)
        
        if extract_data["is_valid_2026"]:
            tags = [faculty, url_data["topic"], url_data["content_type"]] + extract_data["detected_tags"]
            tag_header = f"TAGS: {', '.join(filter(None, tags))}\nSOURCE: {url}\n\n"
            
            full_content = tag_header + extract_data["structured_text"]
            
            chunks = text_splitter.split_text(full_content)
            for chunk in chunks:
                processed_docs.append(Document(
                    page_content=chunk,
                    metadata={
                        "source": url,
                        "faculty": faculty,
                        "topic": url_data["topic"],
                        "year": "2026"
                    }
                ))
            print(f"   ✅ Successfully added ({len(chunks)} chunks)")
        else:
            print(f"   ❌ Rejected")

    except Exception as e:
        print(f"⚠️ Error at url: {url}: {e}")

print(f"\n✨ Done! Created {len(processed_docs)} docs.")
# Out:
# ⏩ Ignored: http://www.ci.tuiasi.ro/download/admitere/2014/prezentare/mobile/index.html
# ⏩ Ignored: http://www.ci.tuiasi.ro/download/admitere/2016/doctorat/ci.pdf
# ⏩ Ignored: http://www.ci.tuiasi.ro/download/admitere/2017/doctorat/informatii%20admitere%202017.pdf
# ⏩ Ignored: http://www.ci.tuiasi.ro/download/admitere/2017/doctorat/tematica%20colocviu_2017a.pdf
# ⏩ Ignored: http://www.ci.tuiasi.ro/download/decanat/calendar/calendar%202016-2017a.pdf
# ⏩ Ignored: http://www.ci.tuiasi.ro/download/decanat/calendar/hs%20199_16.06.2017.pdf
# ⏩ Ignored: http://www.ci.tuiasi.ro/download/decanat/calendar/hs25cau18-19.pdf
#    ❌ Rejected
#    ✅ Successfully added (2 chunks)
#    ❌ Rejected
#    ✅ Successfully added (4 chunks)
#    ✅ Successfully added (3 chunks)
#    ✅ Successfully added (2 chunks)
#    ❌ Rejected
#    ❌ Rejected
# ⏩ Ignored: https://ac.tuiasi.ro/en/studies/masters-degree
#    ❌ Rejected
#    ❌ Rejected
# ⏩ Ignored: https://ac.tuiasi.ro/en/studies/masters-degree/ecs-master-embedded-control-systems
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 23
#      20 if not raw_text or len(raw_text) < 200:
#      21     continue
# ---> 23 extract_resp = llm.invoke(extraction_prompt.format(url=url, raw_content=raw_text))
#      24 extract_data = json.loads(extract_resp)
#      26 if extract_data["is_valid_2026"]:
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\langchain_core\language_models\llms.py:380, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     369 @override
#     370 def invoke(
#     371     self,
#    (...)    376     **kwargs: Any,
#     377 ) -> str:
#     378     config = ensure_config(config)
#     379     return (
# --> 380         self.generate_prompt(
#     381             [self._convert_input(input)],
#     382             stop=stop,
#     383             callbacks=config.get("callbacks"),
#     384             tags=config.get("tags"),
#     385             metadata=config.get("metadata"),
#     386             run_name=config.get("run_name"),
#     387             run_id=config.pop("run_id", None),
#     388             **kwargs,
#     389         )
#     390         .generations[0][0]
#     391         .text
#     392     )
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\langchain_core\language_models\llms.py:791, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     782 @override
#     783 def generate_prompt(
#     784     self,
#    (...)    788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     prompt_strings = [p.to_string() for p in prompts]
# --> 791     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1013, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     994 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     995     run_managers = [
#     996         callback_manager.on_llm_start(
#     997             self._serialized,
#    (...)   1011         )
#    1012     ]
# -> 1013     return self._generate_helper(
#    1014         prompts,
#    1015         stop,
#    1016         run_managers,
#    1017         new_arg_supported=bool(new_arg_supported),
#    1018         **kwargs,
#    1019     )
#    1020 if len(missing_prompts) > 0:
#    1021     run_managers = [
#    1022         callback_managers[idx].on_llm_start(
#    1023             self._serialized,
#    (...)   1030         for idx in missing_prompt_idxs
#    1031     ]
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\langchain_core\language_models\llms.py:817, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     806 def _generate_helper(
#     807     self,
#     808     prompts: list[str],
#    (...)    813     **kwargs: Any,
#     814 ) -> LLMResult:
#     815     try:
#     816         output = (
# --> 817             self._generate(
#     818                 prompts,
#     819                 stop=stop,
#     820                 # TODO: support multiple run managers
#     821                 run_manager=run_managers[0] if run_managers else None,
#     822                 **kwargs,
#     823             )
#     824             if new_arg_supported
#     825             else self._generate(prompts, stop=stop)
#     826         )
#     827     except BaseException as e:
#     828         for run_manager in run_managers:
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\langchain_ollama\llms.py:456, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     454 generations = []
#     455 for prompt in prompts:
# --> 456     final_chunk = self._stream_with_aggregation(
#     457         prompt,
#     458         stop=stop,
#     459         run_manager=run_manager,
#     460         verbose=self.verbose,
#     461         **kwargs,
#     462     )
#     463     generations.append([final_chunk])
#     464 return LLMResult(generations=generations)
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\langchain_ollama\llms.py:415, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     413 final_chunk = None
#     414 thinking_content = ""
# --> 415 for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     416     if not isinstance(stream_resp, str):
#     417         if stream_resp.get("thinking"):
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\langchain_ollama\llms.py:359, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     352 def _create_generate_stream(
#     353     self,
#     354     prompt: str,
#     355     stop: list[str] | None = None,
#     356     **kwargs: Any,
#     357 ) -> Iterator[Mapping[str, Any] | str]:
#     358     if self._client:
# --> 359         yield from self._client.generate(
#     360             **self._generate_params(prompt, stop=stop, **kwargs)
#     361         )
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\ollama\_client.py:181, in Client._request.<locals>.inner()
#     178   e.response.read()
#     179   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 181 for line in r.iter_lines():
#     182   part = json.loads(line)
#     183   if err := part.get('error'):
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpx\_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpx\_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\ChatBotAdmitere\.venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
